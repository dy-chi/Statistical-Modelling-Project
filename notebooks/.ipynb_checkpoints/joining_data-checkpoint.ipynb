# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import pandas as pd
import seaborn as sbn
import sqlite3
import json
import numpy as np

# %%
#stations infomation from city bikes API
stations=pd.read_csv('data/initial_stations_df.csv')
#station ID with lat longs and elevations
stat_elev=pd.read_csv('data/Station_Elevations.csv')

# %%
#merge stations with station elevation
stations.rename(columns={'id':'station_id'}, inplace=True)
stations=stations.merge(stat_elev, on='station_id')
stations
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 1              6           5  983514094dd808b1604da2dcfc2d09af   37.336188
# 2             12          11  da17603652106fda93da4e255a5b0a22   37.322125
# 3             14           0  7a21c92b3b4cd2f7759107b4fdebf869   37.323678
# 4             24           2  ce34d38fb230a23c1ced12d1e16df294   37.325998
# ..           ...         ...                               ...         ...
# 519            5           0  d2ac19a2bb356f022983008bcd6ca5e1   37.767820
# 520            3           5  db8d54f6cc7dcbbf1d74783000539749   37.770938
# 521            5           0  6aba782b9e02d7ae351e6e9f81a7c330   37.768730
# 522            9          10  1b3d97eca9393abbf229aef9b3f80fda   37.731921
# 523           24           3  051b0abcc6ba494a27fc5ee5b0f8acf7   37.768384
#
#      longitude_x                        name                    timestamp  \
# 0    -122.270582     Harmon St at Adeline St  2023-08-22T02:33:57.545000Z
# 1    -121.889277  Fountain Alley at S 2nd St  2023-08-22T02:33:57.120000Z
# 2    -121.881090            Oak St at 1st St  2023-08-22T02:33:57.524000Z
# 3    -121.874119             Bestor Art Park  2023-08-22T02:33:57.243000Z
# 4    -121.877120       5th St at Virginia St  2023-08-22T02:33:57.456000Z
# ..           ...                         ...                          ...
# 519  -122.501868              Chain O' Lakes  2023-08-22T02:33:57.057000Z
# 520  -122.477116                  Stowe Lake  2023-08-22T02:33:57.058000Z
# 521  -122.459429               Bowling Green  2023-08-22T02:33:57.060000Z
# 522  -122.389886       Lane St at Revere Ave  2023-08-22T02:33:57.561000Z
# 523  -122.451967     Waller St at Shrader St  2023-08-22T02:33:57.428000Z
#
#      extra_ebikes  extra_has_ebikes  extra_last_updated  ...  \
# 0               0              True          1692671559  ...
# 1               0              True          1692671546  ...
# 2               0              True          1692671450  ...
# 3               0              True          1692671557  ...
# 4               1              True          1692671522  ...
# ..            ...               ...                 ...  ...
# 519             0              True          1691418718  ...
# 520             5              True          1691418745  ...
# 521             0              True          1691418758  ...
# 522             2              True          1692671481  ...
# 523             3              True          1692671543  ...
#
#                extra_rental_uris_android                extra_rental_uris_ios  \
# 0    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 1    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 2    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 3    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 4    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# ..                                   ...                                  ...
# 519  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 520  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 521  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 522  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 523  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
#
#     extra_renting extra_returning  extra_slots  \
# 0               1               1           15
# 1               1               1           11
# 2               1               1           23
# 3               1               1           15
# 4               1               1           27
# ..            ...             ...          ...
# 519             1               1            5
# 520             1               1            8
# 521             1               1            5
# 522             1               1           19
# 523             1               1           27
#
#                                 extra_uid  \
# 0    fd89514c-f878-4cd5-8113-8e5beead44de
# 1    d12ba265-5bfe-4a00-a19a-a7299822bd65
# 2    0fd9a51c-67ac-4048-b531-bff644b82f47
# 3    46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f
# 4    bb54f5c8-5578-4167-9599-8e55154de4fd
# ..                                    ...
# 519                   1841972814951361204
# 520                   1841972814951361202
# 521                   1841972814951361200
# 522  dfaaaa16-03ba-40b5-8360-6ebfc97ea541
# 523  7d15210b-55fb-4456-8281-781cfa9d5594
#
#                                          extra_address longitude_y latitude_y  \
# 0                                                  NaN -122.270582  37.849735
# 1                                                  NaN -121.889277  37.336188
# 2                                                  NaN -121.881090  37.322125
# 3                                                  NaN -121.874119  37.323678
# 4                                                  NaN -121.877120  37.325998
# ..                                                 ...         ...        ...
# 519  Chain of Lakes Dr E, San Francisco, CA 94121, ... -122.501868  37.767820
# 520  50 Stow Lake Dr, San Francisco, CA 94118, Unit... -122.477116  37.770938
# 521  Bowling Green Dr, San Francisco, CA 94118, Uni... -122.459429  37.768730
# 522                                                NaN -122.389886  37.731921
# 523                                                NaN -122.451967  37.768384
#
#      elevation
# 0    32.928356
# 1    25.925880
# 2    31.710926
# 3    30.782372
# 4    30.175741
# ..         ...
# 519  24.829159
# 520  84.925842
# 521  76.045532
# 522  26.973791
# 523  82.717949
#
# [524 rows x 22 columns]

# %%
station_size=stations['free_bikes']+stations['empty_slots']
use_ratio=stations['free_bikes']/station_size

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
sbn.regplot(data=stations, x='free_bikes', y='elevation', scatter_kws={'alpha':0.15})
# Out:
# <Axes: xlabel='free_bikes', ylabel='elevation'>

# %% [markdown]
# There is a slight trend where the number of free bikes increases as elevation falls.
#
# This may be caused by riders tending to take trips that are  downhill.
#
# Some lurking variables may be the size of the bike station rentals being greater at lower elevations, so it would be less likely (or impossible) for there to be more 25-30 free bikes if the total station size is never that high for stations at high elevations
#
# I will now look to see if there is any correlation between station size and elevation

# %%
station_size.describe()
# Out:
# count    524.000000
# mean      21.032443
# std        5.677174
# min        1.000000
# 25%       18.000000
# 50%       20.000000
# 75%       25.000000
# max       41.000000
# dtype: float64

# %%
sbn.regplot(data=stations, x=station_size, y='elevation', scatter_kws={'alpha':0.15})
# Out:
# <Axes: ylabel='elevation'>

# %% [markdown]
# It seems there are no large stations (>30 spots) above 80m, while there are about 5 stations between size 5-10 above 80m. This might cause some issues with using the actual numbers. Perhaps using normalized values would be better...

# %%
sbn.regplot(data=stations, x=use_ratio, y='elevation', scatter_kws={'alpha':0.15})
# Out:
# <Axes: ylabel='elevation'>

# %% [markdown]
# So the trend appears to have become less noticable, if not non-existent using the use ratio. free_bikes/station_size
#
# Upon reflection, this may be because the system is dynamic and therefore any sustained trend of bikes piling up at lower elevations is not sustainable, eventually there would be no bikes at higher elevations
#
# If their is a trend of riders preferring downhill routes between stations, the trend would have to be offset b station workers moving the bikes back to higher locations periodically and therefore a single timeslice of the data would not show the trend
#
#
# Further tables would have to be analyzed, tracking activity levels, and somehow flagging events that are not trips done by customers. Or perhaps taking multiple timeslices throughout the day and seeing what the chances are for a bike to be free at any given time. Unless the restocking happens very often, you should still see affects of customer trips

# %% [markdown]
# # Using Yelp and Foursquare Data

# %% [markdown]
# ##### We have elevation data from each venue from Foursquare and Yelp. I will use this to measure
# - ###### if a bike station is higher or lower than the mean of venues
#     - get an average elevation for venues within a 100m area of the bike station
#     - check wether the station elevation is signficantly higher or lower. (more than 1m higher or lower should be enough)
#
# - ##### if the bike station is likely to be in a hilly location with respect to venues
#     - is the spread betwen max and min large
#     - if there are enough venues, look at the std
#     - this will only be appropriate for stations with more than two venues and be more useful the more venues there are

# %%
yelp_venue_elev=pd.read_csv('yelp_venue_elev.csv')
yelp_venue_elev
# Out:
#                yelp_venue_id   Longitude   Latitude  Elevation
# 0     QB7-zmun5zXhnNnGXs-LDA -122.269850  37.809050   7.224932
# 1     3k0Nz03m8rKDiGHtMevBFQ -121.900830  37.332970  25.688417
# 2     xfGxyVapMNlAlqQULvyG5Q -122.422302  37.744076  29.704712
# 3     humRe1SGupNdDJUxEdDmMg -122.421562  37.759861  16.017796
# 4     ocbfMG-H8Ov8v5nz1AjlZg -122.024290  36.970170   4.286106
# ...                      ...         ...        ...        ...
# 1945  ogb0Fb6T0t60ls16jED3jw -121.912002  37.332848  30.280857
# 1946  _gHU7DSK2gFVRLx651c8ig -122.421460  37.773256  16.575678
# 1947  LxnbHJlFKjHRZeQqo3Tm5Q -122.434364  37.788940  52.898926
# 1948  gg--F2Z-X2Qh1fkkm1ODHA -122.414823  37.804010   7.037208
# 1949  2ziP1oSBhCjY9I_i-zKhjQ -122.244954  37.791784  10.250802
#
# [1950 rows x 4 columns]

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
connection = sqlite3.connect('CityBike_Project.db')

# Connect to the database or create if not exists
connection = sqlite3.connect('CityBike_Project.db')

# Create a cursor
cursor = connection.cursor()
# Create a table
create_table_query ="CREATE TABLE IF NOT EXISTS stations (station_id TEXT PRIMARY KEY,longitude REAL,latitude REAL,elevation REAL)"
cursor.execute(create_table_query)

connection.commit()
connection.close()

# %%
# Connect to the SQLite database
conn = sqlite3.connect("CityBike_Project.db")  # Replace with your database name

df=stations

# Specify the table name and insert the data
table_name = "stations"  # Replace with your table name
df.to_sql(table_name, conn, if_exists='replace', index=False)

# Close the connection
conn.close()

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
# Connect to the SQLite database

conn = sqlite3.connect('CityBike_Project.db')
# Create a cursor object
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
table_names = cursor.fetchall()

# %%
table_names
# Out:
# [('yelp_venue_elev',),
#  ('stat_ylp_venues',),
#  ('stations_venues_yelp_melted',),
#  ('stations',)]

# %%
cursor.execute("SELECT * FROM stations;")
rows = cursor.fetchall()

# %%
df = pd.DataFrame(rows, columns=[col[0] for col in cursor.description])

# %%
df
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 1              6           5  983514094dd808b1604da2dcfc2d09af   37.336188
# 2             12          11  da17603652106fda93da4e255a5b0a22   37.322125
# 3             14           0  7a21c92b3b4cd2f7759107b4fdebf869   37.323678
# 4             24           2  ce34d38fb230a23c1ced12d1e16df294   37.325998
# ..           ...         ...                               ...         ...
# 519            5           0  d2ac19a2bb356f022983008bcd6ca5e1   37.767820
# 520            3           5  db8d54f6cc7dcbbf1d74783000539749   37.770938
# 521            5           0  6aba782b9e02d7ae351e6e9f81a7c330   37.768730
# 522            9          10  1b3d97eca9393abbf229aef9b3f80fda   37.731921
# 523           24           3  051b0abcc6ba494a27fc5ee5b0f8acf7   37.768384
#
#      longitude_x                        name                    timestamp  \
# 0    -122.270582     Harmon St at Adeline St  2023-08-22T02:33:57.545000Z
# 1    -121.889277  Fountain Alley at S 2nd St  2023-08-22T02:33:57.120000Z
# 2    -121.881090            Oak St at 1st St  2023-08-22T02:33:57.524000Z
# 3    -121.874119             Bestor Art Park  2023-08-22T02:33:57.243000Z
# 4    -121.877120       5th St at Virginia St  2023-08-22T02:33:57.456000Z
# ..           ...                         ...                          ...
# 519  -122.501868              Chain O' Lakes  2023-08-22T02:33:57.057000Z
# 520  -122.477116                  Stowe Lake  2023-08-22T02:33:57.058000Z
# 521  -122.459429               Bowling Green  2023-08-22T02:33:57.060000Z
# 522  -122.389886       Lane St at Revere Ave  2023-08-22T02:33:57.561000Z
# 523  -122.451967     Waller St at Shrader St  2023-08-22T02:33:57.428000Z
#
#      extra_ebikes  extra_has_ebikes  extra_last_updated  ...  \
# 0               0                 1          1692671559  ...
# 1               0                 1          1692671546  ...
# 2               0                 1          1692671450  ...
# 3               0                 1          1692671557  ...
# 4               1                 1          1692671522  ...
# ..            ...               ...                 ...  ...
# 519             0                 1          1691418718  ...
# 520             5                 1          1691418745  ...
# 521             0                 1          1691418758  ...
# 522             2                 1          1692671481  ...
# 523             3                 1          1692671543  ...
#
#                extra_rental_uris_android                extra_rental_uris_ios  \
# 0    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 1    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 2    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 3    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 4    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# ..                                   ...                                  ...
# 519  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 520  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 521  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 522  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 523  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
#
#     extra_renting extra_returning  extra_slots  \
# 0               1               1           15
# 1               1               1           11
# 2               1               1           23
# 3               1               1           15
# 4               1               1           27
# ..            ...             ...          ...
# 519             1               1            5
# 520             1               1            8
# 521             1               1            5
# 522             1               1           19
# 523             1               1           27
#
#                                 extra_uid  \
# 0    fd89514c-f878-4cd5-8113-8e5beead44de
# 1    d12ba265-5bfe-4a00-a19a-a7299822bd65
# 2    0fd9a51c-67ac-4048-b531-bff644b82f47
# 3    46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f
# 4    bb54f5c8-5578-4167-9599-8e55154de4fd
# ..                                    ...
# 519                   1841972814951361204
# 520                   1841972814951361202
# 521                   1841972814951361200
# 522  dfaaaa16-03ba-40b5-8360-6ebfc97ea541
# 523  7d15210b-55fb-4456-8281-781cfa9d5594
#
#                                          extra_address longitude_y latitude_y  \
# 0                                                 None -122.270582  37.849735
# 1                                                 None -121.889277  37.336188
# 2                                                 None -121.881090  37.322125
# 3                                                 None -121.874119  37.323678
# 4                                                 None -121.877120  37.325998
# ..                                                 ...         ...        ...
# 519  Chain of Lakes Dr E, San Francisco, CA 94121, ... -122.501868  37.767820
# 520  50 Stow Lake Dr, San Francisco, CA 94118, Unit... -122.477116  37.770938
# 521  Bowling Green Dr, San Francisco, CA 94118, Uni... -122.459429  37.768730
# 522                                               None -122.389886  37.731921
# 523                                               None -122.451967  37.768384
#
#      elevation
# 0    32.928356
# 1    25.925880
# 2    31.710926
# 3    30.782372
# 4    30.175741
# ..         ...
# 519  24.829159
# 520  84.925842
# 521  76.045532
# 522  26.973791
# 523  82.717949
#
# [524 rows x 22 columns]

# %%
stations
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 1              6           5  983514094dd808b1604da2dcfc2d09af   37.336188
# 2             12          11  da17603652106fda93da4e255a5b0a22   37.322125
# 3             14           0  7a21c92b3b4cd2f7759107b4fdebf869   37.323678
# 4             24           2  ce34d38fb230a23c1ced12d1e16df294   37.325998
# ..           ...         ...                               ...         ...
# 519            5           0  d2ac19a2bb356f022983008bcd6ca5e1   37.767820
# 520            3           5  db8d54f6cc7dcbbf1d74783000539749   37.770938
# 521            5           0  6aba782b9e02d7ae351e6e9f81a7c330   37.768730
# 522            9          10  1b3d97eca9393abbf229aef9b3f80fda   37.731921
# 523           24           3  051b0abcc6ba494a27fc5ee5b0f8acf7   37.768384
#
#      longitude_x                        name                    timestamp  \
# 0    -122.270582     Harmon St at Adeline St  2023-08-22T02:33:57.545000Z
# 1    -121.889277  Fountain Alley at S 2nd St  2023-08-22T02:33:57.120000Z
# 2    -121.881090            Oak St at 1st St  2023-08-22T02:33:57.524000Z
# 3    -121.874119             Bestor Art Park  2023-08-22T02:33:57.243000Z
# 4    -121.877120       5th St at Virginia St  2023-08-22T02:33:57.456000Z
# ..           ...                         ...                          ...
# 519  -122.501868              Chain O' Lakes  2023-08-22T02:33:57.057000Z
# 520  -122.477116                  Stowe Lake  2023-08-22T02:33:57.058000Z
# 521  -122.459429               Bowling Green  2023-08-22T02:33:57.060000Z
# 522  -122.389886       Lane St at Revere Ave  2023-08-22T02:33:57.561000Z
# 523  -122.451967     Waller St at Shrader St  2023-08-22T02:33:57.428000Z
#
#      extra_ebikes  extra_has_ebikes  extra_last_updated  ...  \
# 0               0              True          1692671559  ...
# 1               0              True          1692671546  ...
# 2               0              True          1692671450  ...
# 3               0              True          1692671557  ...
# 4               1              True          1692671522  ...
# ..            ...               ...                 ...  ...
# 519             0              True          1691418718  ...
# 520             5              True          1691418745  ...
# 521             0              True          1691418758  ...
# 522             2              True          1692671481  ...
# 523             3              True          1692671543  ...
#
#                extra_rental_uris_android                extra_rental_uris_ios  \
# 0    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 1    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 2    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 3    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 4    https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# ..                                   ...                                  ...
# 519  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 520  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 521  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 522  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
# 523  https://sfo.lft.to/lastmile_qr_scan  https://sfo.lft.to/lastmile_qr_scan
#
#     extra_renting extra_returning  extra_slots  \
# 0               1               1           15
# 1               1               1           11
# 2               1               1           23
# 3               1               1           15
# 4               1               1           27
# ..            ...             ...          ...
# 519             1               1            5
# 520             1               1            8
# 521             1               1            5
# 522             1               1           19
# 523             1               1           27
#
#                                 extra_uid  \
# 0    fd89514c-f878-4cd5-8113-8e5beead44de
# 1    d12ba265-5bfe-4a00-a19a-a7299822bd65
# 2    0fd9a51c-67ac-4048-b531-bff644b82f47
# 3    46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f
# 4    bb54f5c8-5578-4167-9599-8e55154de4fd
# ..                                    ...
# 519                   1841972814951361204
# 520                   1841972814951361202
# 521                   1841972814951361200
# 522  dfaaaa16-03ba-40b5-8360-6ebfc97ea541
# 523  7d15210b-55fb-4456-8281-781cfa9d5594
#
#                                          extra_address longitude_y latitude_y  \
# 0                                                  NaN -122.270582  37.849735
# 1                                                  NaN -121.889277  37.336188
# 2                                                  NaN -121.881090  37.322125
# 3                                                  NaN -121.874119  37.323678
# 4                                                  NaN -121.877120  37.325998
# ..                                                 ...         ...        ...
# 519  Chain of Lakes Dr E, San Francisco, CA 94121, ... -122.501868  37.767820
# 520  50 Stow Lake Dr, San Francisco, CA 94118, Unit... -122.477116  37.770938
# 521  Bowling Green Dr, San Francisco, CA 94118, Uni... -122.459429  37.768730
# 522                                                NaN -122.389886  37.731921
# 523                                                NaN -122.451967  37.768384
#
#      elevation
# 0    32.928356
# 1    25.925880
# 2    31.710926
# 3    30.782372
# 4    30.175741
# ..         ...
# 519  24.829159
# 520  84.925842
# 521  76.045532
# 522  26.973791
# 523  82.717949
#
# [524 rows x 22 columns]

# %% [markdown]
# import list of venues for yelp

# %% [markdown]
# # Cleaning Yelp venues data base of lat long tuples so there is only store id

# %%
stat_ylp_venues=pd.read_csv('data/df_yelp_head_tail_250.csv')

# %%
stat_ylp_venues
# Out:
#                            station_id  \
# 0    d0e8f4f1834b7b33a3faf8882f567ab8
# 1    983514094dd808b1604da2dcfc2d09af
# 2    da17603652106fda93da4e255a5b0a22
# 3    7a21c92b3b4cd2f7759107b4fdebf869
# 4    ce34d38fb230a23c1ced12d1e16df294
# ..                                ...
# 519  d2ac19a2bb356f022983008bcd6ca5e1
# 520  db8d54f6cc7dcbbf1d74783000539749
# 521  6aba782b9e02d7ae351e6e9f81a7c330
# 522  1b3d97eca9393abbf229aef9b3f80fda
# 523  051b0abcc6ba494a27fc5ee5b0f8acf7
#
#                                                store_1  \
# 0    ('OjMumhyL26n5fDZ2CQLnyg', 37.850300662973346,...
# 1    ('berEiBE0fDM-HiYFEAf-Ww', 37.3361378, -121.88...
# 2                                                  NaN
# 3    ('5bWsqTiJ-WiLz0tdMwBg7Q', 37.3234314189821, -...
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520    ('pn-KO9C7bLiDqfkZiTFqdA', 37.77064, -122.4771)
# 521                                                NaN
# 522                                                NaN
# 523  ('kOYj2sGMZnyC1lU-_Uw5fA', 37.7691434, -122.45...
#
#                                                store_2  \
# 0    ('-EpmBwODsvQ6gHx2IuVO5w', 37.85001740687401, ...
# 1    ('qArqv7Sl3-kz7m-I0-pyuw', 37.336263, -121.889...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520   ('jO27_oneFWdZKXf9vlXJTA', 37.76737, -122.47716)
# 521                                                NaN
# 522                                                NaN
# 523  ('TlBFKt2N2eSEBpN-UZmDBw', 37.769217, -122.452...
#
#                                                store_3  \
# 0     ('LP6NBMIa3dxinjgtOxMEZg', 37.85004, -122.27053)
# 1     ('-A2EzuWuOhzGW2mkzr9sLg', 37.33638, -121.88988)
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523  ('yVN5m2ARIT3kcLCG8EVglQ', 37.7691841125488, -...
#
#                                                store_4  \
# 0    ('guObf4lR-TsRD1IHJni06g', 37.849494934082, -1...
# 1    ('KZM6GxmdYak3ahLUJuWmZw', 37.3367777, -121.88...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523  ('Z661e-IOrGuCcvLLe1lS1w', 37.7691508621399, -...
#
#                                                store_5  \
# 0    ('3twXqUphnT3qi4ThSzQwQQ', 37.8492637746169, -...
# 1    ('HzReUs8NWZN15ntyHfH-mA', 37.336321680671986,...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523  ('bENuHq5nDdvSEDsIxSBnQA', 37.7678833007812, -...
#
#                                                store_6  \
# 0                                                  NaN
# 1    ('umMDGhsrt-Zhv6ZIw1aPdw', 37.3369476067549, -...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523  ('-dWwlYLcSsVNMNIkBdwWOQ', 37.7691694, -122.45...
#
#                                               store_7  \
# 0                                                 NaN
# 1    ('RMsYXfBmpmAye5a9IyN2SA', 37.33668, -121.88895)
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 519                                               NaN
# 520                                               NaN
# 521                                               NaN
# 522                                               NaN
# 523  ('fiMASaLlwho1Y7YMApYMKA', 37.76919, -122.45234)
#
#                                                store_8  \
# 0                                                  NaN
# 1    ('ND5BY7eKMCeeu2kcQEwXxg', 37.3369298871105, -...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                                store_9  ...  \
# 0                                                  NaN  ...
# 1    ('bwEFBcw8y30lqtAMWXLPxg', 37.3352859388708, -...  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 519                                                NaN  ...
# 520                                                NaN  ...
# 521                                                NaN  ...
# 522                                                NaN  ...
# 523                                                NaN  ...
#
#                                               store_11  \
# 0                                                  NaN
# 1    ('lhh0RQP0SRd1YTKwkEKZCg', 37.335379312495746,...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                               store_12  \
# 0                                                  NaN
# 1    ('pWUaPh4yHqe6GekSzJzcug', 37.3370318639, -121...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                               store_13  \
# 0                                                  NaN
# 1    ('LmBPTn52vSmaCTpKnwSJ4A', 37.336807066738864,...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                               store_14  \
# 0                                                  NaN
# 1    ('e-f4l-iml9QbM50REiR0rQ', 37.335288, -121.889...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                               store_15  \
# 0                                                  NaN
# 1    ('SQPgbmrj0swjj_b5UyiCPA', 37.335419, -121.889...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                               store_16  \
# 0                                                  NaN
# 1    ('k6G6EMUaDEMZ03ZSG4U9Tw', 37.33544000053426, ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                               store_17  \
# 0                                                  NaN
# 1    ('zSA32AX3KUury9bjYhZhAQ', 37.3361645751218, -...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                               store_18  \
# 0                                                  NaN
# 1    ('NmLkRCu1NnxcsiowhlcPrw', 37.3363299, -121.88...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                               store_19  \
# 0                                                  NaN
# 1    ('2jq8ttClZhtfQS4psBwahw', 37.3353147292992, -...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
#                                               store_20
# 0                                                  NaN
# 1    ('8ype6-KH6iSNQijrRSgRmg', 37.3353183364266, -...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
#
# [524 rows x 21 columns]

# %%
#extracting venue_id
stat_ylp_venues['store_1'][0][2:24]
# Out:
# 'OjMumhyL26n5fDZ2CQLnyg'

# %%
stat_ylp_venues
n=len(stat_ylp_venues)

for rowindex in range(n):
    for col_name in (stat_ylp_venues.columns[1:21]):
        if pd.notna(stat_ylp_venues[col_name][rowindex]):
            stat_ylp_venues[col_name][rowindex]=stat_ylp_venues[col_name][rowindex][2:24]

# %% [markdown]
# # Cleaned store IDs

# %%
stat_ylp_venues
# Out:
#                            station_id                 store_1  \
# 0    d0e8f4f1834b7b33a3faf8882f567ab8  OjMumhyL26n5fDZ2CQLnyg
# 1    983514094dd808b1604da2dcfc2d09af  berEiBE0fDM-HiYFEAf-Ww
# 2    da17603652106fda93da4e255a5b0a22                     NaN
# 3    7a21c92b3b4cd2f7759107b4fdebf869  5bWsqTiJ-WiLz0tdMwBg7Q
# 4    ce34d38fb230a23c1ced12d1e16df294                     NaN
# ..                                ...                     ...
# 519  d2ac19a2bb356f022983008bcd6ca5e1                     NaN
# 520  db8d54f6cc7dcbbf1d74783000539749  pn-KO9C7bLiDqfkZiTFqdA
# 521  6aba782b9e02d7ae351e6e9f81a7c330                     NaN
# 522  1b3d97eca9393abbf229aef9b3f80fda                     NaN
# 523  051b0abcc6ba494a27fc5ee5b0f8acf7  kOYj2sGMZnyC1lU-_Uw5fA
#
#                     store_2                 store_3                 store_4  \
# 0    -EpmBwODsvQ6gHx2IuVO5w  LP6NBMIa3dxinjgtOxMEZg  guObf4lR-TsRD1IHJni06g
# 1    qArqv7Sl3-kz7m-I0-pyuw  -A2EzuWuOhzGW2mkzr9sLg  KZM6GxmdYak3ahLUJuWmZw
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520  jO27_oneFWdZKXf9vlXJTA                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523  TlBFKt2N2eSEBpN-UZmDBw  yVN5m2ARIT3kcLCG8EVglQ  Z661e-IOrGuCcvLLe1lS1w
#
#                     store_5                 store_6                 store_7  \
# 0    3twXqUphnT3qi4ThSzQwQQ                     NaN                     NaN
# 1    HzReUs8NWZN15ntyHfH-mA  umMDGhsrt-Zhv6ZIw1aPdw  RMsYXfBmpmAye5a9IyN2SA
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520                     NaN                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523  bENuHq5nDdvSEDsIxSBnQA  -dWwlYLcSsVNMNIkBdwWOQ  fiMASaLlwho1Y7YMApYMKA
#
#                     store_8                 store_9  ...  \
# 0                       NaN                     NaN  ...
# 1    ND5BY7eKMCeeu2kcQEwXxg  bwEFBcw8y30lqtAMWXLPxg  ...
# 2                       NaN                     NaN  ...
# 3                       NaN                     NaN  ...
# 4                       NaN                     NaN  ...
# ..                      ...                     ...  ...
# 519                     NaN                     NaN  ...
# 520                     NaN                     NaN  ...
# 521                     NaN                     NaN  ...
# 522                     NaN                     NaN  ...
# 523                     NaN                     NaN  ...
#
#                    store_11                store_12                store_13  \
# 0                       NaN                     NaN                     NaN
# 1    lhh0RQP0SRd1YTKwkEKZCg  pWUaPh4yHqe6GekSzJzcug  LmBPTn52vSmaCTpKnwSJ4A
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520                     NaN                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523                     NaN                     NaN                     NaN
#
#                    store_14                store_15                store_16  \
# 0                       NaN                     NaN                     NaN
# 1    e-f4l-iml9QbM50REiR0rQ  SQPgbmrj0swjj_b5UyiCPA  k6G6EMUaDEMZ03ZSG4U9Tw
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520                     NaN                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523                     NaN                     NaN                     NaN
#
#                    store_17                store_18                store_19  \
# 0                       NaN                     NaN                     NaN
# 1    zSA32AX3KUury9bjYhZhAQ  NmLkRCu1NnxcsiowhlcPrw  2jq8ttClZhtfQS4psBwahw
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520                     NaN                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523                     NaN                     NaN                     NaN
#
#                    store_20
# 0                       NaN
# 1    8ype6-KH6iSNQijrRSgRmg
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 519                     NaN
# 520                     NaN
# 521                     NaN
# 522                     NaN
# 523                     NaN
#
# [524 rows x 21 columns]

# %% [markdown]
# # Adding Yelp tables to SQLite3

# %%
#import stations yelp venues
df = yelp_venue_elev
print(df)
table_name = 'yelp_venue_elev'

conn = sqlite3.connect('CityBike_Project.db')
query = f'Create table if not Exists {table_name} (yelp_venue_id TEXT PRIMARY KEY,longitude REAL,latitude REAL,elevation REAL)'
conn.execute(query)
df.to_sql(table_name,conn,if_exists='replace',index=False)
conn.commit()
conn.close()
# Out:
#                yelp_venue_id   Longitude   Latitude  Elevation
# 0     QB7-zmun5zXhnNnGXs-LDA -122.269850  37.809050   7.224932
# 1     3k0Nz03m8rKDiGHtMevBFQ -121.900830  37.332970  25.688417
# 2     xfGxyVapMNlAlqQULvyG5Q -122.422302  37.744076  29.704712
# 3     humRe1SGupNdDJUxEdDmMg -122.421562  37.759861  16.017796
# 4     ocbfMG-H8Ov8v5nz1AjlZg -122.024290  36.970170   4.286106
# ...                      ...         ...        ...        ...
# 1945  ogb0Fb6T0t60ls16jED3jw -121.912002  37.332848  30.280857
# 1946  _gHU7DSK2gFVRLx651c8ig -122.421460  37.773256  16.575678
# 1947  LxnbHJlFKjHRZeQqo3Tm5Q -122.434364  37.788940  52.898926
# 1948  gg--F2Z-X2Qh1fkkm1ODHA -122.414823  37.804010   7.037208
# 1949  2ziP1oSBhCjY9I_i-zKhjQ -122.244954  37.791784  10.250802
#
# [1950 rows x 4 columns]

# %%
#import stations yelp venues
df = stat_ylp_venues

table_name = 'stat_ylp_venues'

conn = sqlite3.connect('CityBike_Project.db')
query = f'Create table if not Exists {table_name} (station_id TEXT PRIMARY KEY)'
conn.execute(query)
df.to_sql(table_name,conn,if_exists='replace',index=False)
conn.commit()
conn.close()

# %%
#check database

# %%
# Connect to the SQLite database

conn = sqlite3.connect('CityBike_Project.db')
# Create a cursor object
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
table_names = cursor.fetchall()

# %%
table_names
# Out:
# [('stations_venues_yelp_melted',),
#  ('stations',),
#  ('yelp_venue_elev',),
#  ('stat_ylp_venues',)]

# %%
cursor.execute("SELECT * FROM yelp_venue_elev;")
rows = cursor.fetchall()
df = pd.DataFrame(rows, columns=[col[0] for col in cursor.description])
df
# Out:
#                yelp_venue_id   Longitude   Latitude  Elevation
# 0     QB7-zmun5zXhnNnGXs-LDA -122.269850  37.809050   7.224932
# 1     3k0Nz03m8rKDiGHtMevBFQ -121.900830  37.332970  25.688417
# 2     xfGxyVapMNlAlqQULvyG5Q -122.422302  37.744076  29.704712
# 3     humRe1SGupNdDJUxEdDmMg -122.421562  37.759861  16.017796
# 4     ocbfMG-H8Ov8v5nz1AjlZg -122.024290  36.970170   4.286106
# ...                      ...         ...        ...        ...
# 1945  ogb0Fb6T0t60ls16jED3jw -121.912002  37.332848  30.280857
# 1946  _gHU7DSK2gFVRLx651c8ig -122.421460  37.773256  16.575678
# 1947  LxnbHJlFKjHRZeQqo3Tm5Q -122.434364  37.788940  52.898926
# 1948  gg--F2Z-X2Qh1fkkm1ODHA -122.414823  37.804010   7.037208
# 1949  2ziP1oSBhCjY9I_i-zKhjQ -122.244954  37.791784  10.250802
#
# [1950 rows x 4 columns]

# %%
cursor.execute("SELECT * FROM stat_ylp_venues;")
rows = cursor.fetchall()
df = pd.DataFrame(rows, columns=[col[0] for col in cursor.description])
df
# Out:
#                            station_id                 store_1  \
# 0    d0e8f4f1834b7b33a3faf8882f567ab8  OjMumhyL26n5fDZ2CQLnyg
# 1    983514094dd808b1604da2dcfc2d09af  berEiBE0fDM-HiYFEAf-Ww
# 2    da17603652106fda93da4e255a5b0a22                    None
# 3    7a21c92b3b4cd2f7759107b4fdebf869  5bWsqTiJ-WiLz0tdMwBg7Q
# 4    ce34d38fb230a23c1ced12d1e16df294                    None
# ..                                ...                     ...
# 519  d2ac19a2bb356f022983008bcd6ca5e1                    None
# 520  db8d54f6cc7dcbbf1d74783000539749  pn-KO9C7bLiDqfkZiTFqdA
# 521  6aba782b9e02d7ae351e6e9f81a7c330                    None
# 522  1b3d97eca9393abbf229aef9b3f80fda                    None
# 523  051b0abcc6ba494a27fc5ee5b0f8acf7  kOYj2sGMZnyC1lU-_Uw5fA
#
#                     store_2                 store_3                 store_4  \
# 0    -EpmBwODsvQ6gHx2IuVO5w  LP6NBMIa3dxinjgtOxMEZg  guObf4lR-TsRD1IHJni06g
# 1    qArqv7Sl3-kz7m-I0-pyuw  -A2EzuWuOhzGW2mkzr9sLg  KZM6GxmdYak3ahLUJuWmZw
# 2                      None                    None                    None
# 3                      None                    None                    None
# 4                      None                    None                    None
# ..                      ...                     ...                     ...
# 519                    None                    None                    None
# 520  jO27_oneFWdZKXf9vlXJTA                    None                    None
# 521                    None                    None                    None
# 522                    None                    None                    None
# 523  TlBFKt2N2eSEBpN-UZmDBw  yVN5m2ARIT3kcLCG8EVglQ  Z661e-IOrGuCcvLLe1lS1w
#
#                     store_5                 store_6                 store_7  \
# 0    3twXqUphnT3qi4ThSzQwQQ                    None                    None
# 1    HzReUs8NWZN15ntyHfH-mA  umMDGhsrt-Zhv6ZIw1aPdw  RMsYXfBmpmAye5a9IyN2SA
# 2                      None                    None                    None
# 3                      None                    None                    None
# 4                      None                    None                    None
# ..                      ...                     ...                     ...
# 519                    None                    None                    None
# 520                    None                    None                    None
# 521                    None                    None                    None
# 522                    None                    None                    None
# 523  bENuHq5nDdvSEDsIxSBnQA  -dWwlYLcSsVNMNIkBdwWOQ  fiMASaLlwho1Y7YMApYMKA
#
#                     store_8                 store_9  ...  \
# 0                      None                    None  ...
# 1    ND5BY7eKMCeeu2kcQEwXxg  bwEFBcw8y30lqtAMWXLPxg  ...
# 2                      None                    None  ...
# 3                      None                    None  ...
# 4                      None                    None  ...
# ..                      ...                     ...  ...
# 519                    None                    None  ...
# 520                    None                    None  ...
# 521                    None                    None  ...
# 522                    None                    None  ...
# 523                    None                    None  ...
#
#                    store_11                store_12                store_13  \
# 0                      None                    None                    None
# 1    lhh0RQP0SRd1YTKwkEKZCg  pWUaPh4yHqe6GekSzJzcug  LmBPTn52vSmaCTpKnwSJ4A
# 2                      None                    None                    None
# 3                      None                    None                    None
# 4                      None                    None                    None
# ..                      ...                     ...                     ...
# 519                    None                    None                    None
# 520                    None                    None                    None
# 521                    None                    None                    None
# 522                    None                    None                    None
# 523                    None                    None                    None
#
#                    store_14                store_15                store_16  \
# 0                      None                    None                    None
# 1    e-f4l-iml9QbM50REiR0rQ  SQPgbmrj0swjj_b5UyiCPA  k6G6EMUaDEMZ03ZSG4U9Tw
# 2                      None                    None                    None
# 3                      None                    None                    None
# 4                      None                    None                    None
# ..                      ...                     ...                     ...
# 519                    None                    None                    None
# 520                    None                    None                    None
# 521                    None                    None                    None
# 522                    None                    None                    None
# 523                    None                    None                    None
#
#                    store_17                store_18                store_19  \
# 0                      None                    None                    None
# 1    zSA32AX3KUury9bjYhZhAQ  NmLkRCu1NnxcsiowhlcPrw  2jq8ttClZhtfQS4psBwahw
# 2                      None                    None                    None
# 3                      None                    None                    None
# 4                      None                    None                    None
# ..                      ...                     ...                     ...
# 519                    None                    None                    None
# 520                    None                    None                    None
# 521                    None                    None                    None
# 522                    None                    None                    None
# 523                    None                    None                    None
#
#                    store_20
# 0                      None
# 1    8ype6-KH6iSNQijrRSgRmg
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 519                    None
# 520                    None
# 521                    None
# 522                    None
# 523                    None
#
# [524 rows x 21 columns]

# %% [markdown]
# # Find the average elevation of vanues near stations

# %%
#melt experiment

stat_ylp_venues
# Out:
#                            station_id                 store_1  \
# 0    d0e8f4f1834b7b33a3faf8882f567ab8  OjMumhyL26n5fDZ2CQLnyg
# 1    983514094dd808b1604da2dcfc2d09af  berEiBE0fDM-HiYFEAf-Ww
# 2    da17603652106fda93da4e255a5b0a22                     NaN
# 3    7a21c92b3b4cd2f7759107b4fdebf869  5bWsqTiJ-WiLz0tdMwBg7Q
# 4    ce34d38fb230a23c1ced12d1e16df294                     NaN
# ..                                ...                     ...
# 519  d2ac19a2bb356f022983008bcd6ca5e1                     NaN
# 520  db8d54f6cc7dcbbf1d74783000539749  pn-KO9C7bLiDqfkZiTFqdA
# 521  6aba782b9e02d7ae351e6e9f81a7c330                     NaN
# 522  1b3d97eca9393abbf229aef9b3f80fda                     NaN
# 523  051b0abcc6ba494a27fc5ee5b0f8acf7  kOYj2sGMZnyC1lU-_Uw5fA
#
#                     store_2                 store_3                 store_4  \
# 0    -EpmBwODsvQ6gHx2IuVO5w  LP6NBMIa3dxinjgtOxMEZg  guObf4lR-TsRD1IHJni06g
# 1    qArqv7Sl3-kz7m-I0-pyuw  -A2EzuWuOhzGW2mkzr9sLg  KZM6GxmdYak3ahLUJuWmZw
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520  jO27_oneFWdZKXf9vlXJTA                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523  TlBFKt2N2eSEBpN-UZmDBw  yVN5m2ARIT3kcLCG8EVglQ  Z661e-IOrGuCcvLLe1lS1w
#
#                     store_5                 store_6                 store_7  \
# 0    3twXqUphnT3qi4ThSzQwQQ                     NaN                     NaN
# 1    HzReUs8NWZN15ntyHfH-mA  umMDGhsrt-Zhv6ZIw1aPdw  RMsYXfBmpmAye5a9IyN2SA
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520                     NaN                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523  bENuHq5nDdvSEDsIxSBnQA  -dWwlYLcSsVNMNIkBdwWOQ  fiMASaLlwho1Y7YMApYMKA
#
#                     store_8                 store_9  ...  \
# 0                       NaN                     NaN  ...
# 1    ND5BY7eKMCeeu2kcQEwXxg  bwEFBcw8y30lqtAMWXLPxg  ...
# 2                       NaN                     NaN  ...
# 3                       NaN                     NaN  ...
# 4                       NaN                     NaN  ...
# ..                      ...                     ...  ...
# 519                     NaN                     NaN  ...
# 520                     NaN                     NaN  ...
# 521                     NaN                     NaN  ...
# 522                     NaN                     NaN  ...
# 523                     NaN                     NaN  ...
#
#                    store_11                store_12                store_13  \
# 0                       NaN                     NaN                     NaN
# 1    lhh0RQP0SRd1YTKwkEKZCg  pWUaPh4yHqe6GekSzJzcug  LmBPTn52vSmaCTpKnwSJ4A
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520                     NaN                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523                     NaN                     NaN                     NaN
#
#                    store_14                store_15                store_16  \
# 0                       NaN                     NaN                     NaN
# 1    e-f4l-iml9QbM50REiR0rQ  SQPgbmrj0swjj_b5UyiCPA  k6G6EMUaDEMZ03ZSG4U9Tw
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520                     NaN                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523                     NaN                     NaN                     NaN
#
#                    store_17                store_18                store_19  \
# 0                       NaN                     NaN                     NaN
# 1    zSA32AX3KUury9bjYhZhAQ  NmLkRCu1NnxcsiowhlcPrw  2jq8ttClZhtfQS4psBwahw
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 519                     NaN                     NaN                     NaN
# 520                     NaN                     NaN                     NaN
# 521                     NaN                     NaN                     NaN
# 522                     NaN                     NaN                     NaN
# 523                     NaN                     NaN                     NaN
#
#                    store_20
# 0                       NaN
# 1    8ype6-KH6iSNQijrRSgRmg
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 519                     NaN
# 520                     NaN
# 521                     NaN
# 522                     NaN
# 523                     NaN
#
# [524 rows x 21 columns]

# %% [markdown]
# I want a column with stations and a venue id

# %%
melted_stat_ylp_venues = pd.melt(stat_ylp_venues, id_vars=["station_id"], value_name="venue_id")

# %%
melted_stat_ylp_venues=melted_stat_ylp_venues.drop(['variable'], axis=1)

# %%
melted_stat_ylp_venues=melted_stat_ylp_venues.dropna()

# %%
yelp_venue_elev
# Out:
#                yelp_venue_id   Longitude   Latitude  Elevation
# 0     QB7-zmun5zXhnNnGXs-LDA -122.269850  37.809050   7.224932
# 1     3k0Nz03m8rKDiGHtMevBFQ -121.900830  37.332970  25.688417
# 2     xfGxyVapMNlAlqQULvyG5Q -122.422302  37.744076  29.704712
# 3     humRe1SGupNdDJUxEdDmMg -122.421562  37.759861  16.017796
# 4     ocbfMG-H8Ov8v5nz1AjlZg -122.024290  36.970170   4.286106
# ...                      ...         ...        ...        ...
# 1945  ogb0Fb6T0t60ls16jED3jw -121.912002  37.332848  30.280857
# 1946  _gHU7DSK2gFVRLx651c8ig -122.421460  37.773256  16.575678
# 1947  LxnbHJlFKjHRZeQqo3Tm5Q -122.434364  37.788940  52.898926
# 1948  gg--F2Z-X2Qh1fkkm1ODHA -122.414823  37.804010   7.037208
# 1949  2ziP1oSBhCjY9I_i-zKhjQ -122.244954  37.791784  10.250802
#
# [1950 rows x 4 columns]

# %%
stations_venues_yelp_melted=melted_stat_ylp_venues

# %% [markdown]
# Now that I have a database of stations with venues directly I can import this to sqlite

# %%
stations_venues_yelp_melted
# Out:
#                              station_id                venue_id
# 0      d0e8f4f1834b7b33a3faf8882f567ab8  OjMumhyL26n5fDZ2CQLnyg
# 1      983514094dd808b1604da2dcfc2d09af  berEiBE0fDM-HiYFEAf-Ww
# 3      7a21c92b3b4cd2f7759107b4fdebf869  5bWsqTiJ-WiLz0tdMwBg7Q
# 6      b4b0088fb4fbb4587cad9d89ddc092cd  foY-KOyM6pEQL2mjPBu-Sg
# 7      d576652cc151c23d6ec52b8454429d47  KoKgjlFjWjssT2QRQK3vfQ
# ...                                 ...                     ...
# 10399  338a6ebbd36aadefe8e02fe32c0cbad0  EebZ7BVakHz9PWQyCeHrKw
# 10411  7201ad6fe2a1e03ff9ea5749d84c354d  BtWTcdCnC0O5EBF0GgmmaQ
# 10443  366a420aef7c94bd8bcbe1e6557d2f1e  31h9x2wqW_WRJ8t2E5HObQ
# 10456  018bfeb8a511bb60ffbb0cab866667ab  hCpwAHmq9tMcO7DTXtStJQ
# 10461  fa32d245becfeba6d7b6034133e59d95  ekwsDgAbkuc8KXT5SxTLag
#
# [2630 rows x 2 columns]

# %%
#import stations yelp venues
df = stations_venues_yelp_melted

table_name = 'stations_venues_yelp_melted'

conn = sqlite3.connect('CityBike_Project.db')
query = f'Create table if not Exists {table_name} (station_id TEXT, venue_id TEXT)'
conn.execute(query)
df.to_sql(table_name,conn,if_exists='replace',index=False)
conn.commit()
conn.close()

# %% [markdown]
# Find the average elevation for venues near a station, and include the number of venues per station

# %%
conn = sqlite3.connect("CityBike_Project.db")

# Join Table 2 and Table 3, calculate average height for each class
query = """
SELECT s.station_id, AVG(e.Elevation), count(s.venue_id),MAX(e.Elevation) max_venue_elev,MIN(e.Elevation) min_venue_elev
FROM stations_venues_yelp_melted s
JOIN yelp_venue_elev e ON s.venue_id = e.yelp_venue_id
GROUP BY s.station_id
"""
average_venue_elev = pd.read_sql(query, conn)
rows = cursor.fetchall()
# Close the connection
conn.close()

# %%
yelp_venue_elev
# Out:
#                yelp_venue_id   Longitude   Latitude  Elevation
# 0     QB7-zmun5zXhnNnGXs-LDA -122.269850  37.809050   7.224932
# 1     3k0Nz03m8rKDiGHtMevBFQ -121.900830  37.332970  25.688417
# 2     xfGxyVapMNlAlqQULvyG5Q -122.422302  37.744076  29.704712
# 3     humRe1SGupNdDJUxEdDmMg -122.421562  37.759861  16.017796
# 4     ocbfMG-H8Ov8v5nz1AjlZg -122.024290  36.970170   4.286106
# ...                      ...         ...        ...        ...
# 1945  ogb0Fb6T0t60ls16jED3jw -121.912002  37.332848  30.280857
# 1946  _gHU7DSK2gFVRLx651c8ig -122.421460  37.773256  16.575678
# 1947  LxnbHJlFKjHRZeQqo3Tm5Q -122.434364  37.788940  52.898926
# 1948  gg--F2Z-X2Qh1fkkm1ODHA -122.414823  37.804010   7.037208
# 1949  2ziP1oSBhCjY9I_i-zKhjQ -122.244954  37.791784  10.250802
#
# [1950 rows x 4 columns]

# %%
average_venue_elev
# Out:
#                            station_id  AVG(e.Elevation)  count(s.venue_id)  \
# 0    0129b835b33f6afca778ebfb90453aad         26.356956                  2
# 1    0167c2413c3487d67d1dd7d906389959          6.153292                  3
# 2    018bfeb8a511bb60ffbb0cab866667ab         80.644259                 16
# 3    0267ea932e83058a086f124bb3201e01          7.405990                  2
# 4    02744ef00b430de0440ab88ecff71b2d          4.512651                  8
# ..                                ...               ...                ...
# 365  fda7185b4c97e338faf660d39aa119cb         98.539898                 16
# 366  fdf5f4679be9ae94f860552ca46a2648         16.856162                  4
# 367  fdfed17363937bd17e69bb5f32b67257         57.438805                  2
# 368  ff965c7f0bb892bf7053a78b4df24275         21.907272                  3
# 369  fff91ff985e5954b8b94e603a44db763          4.096888                  4
#
#      max_venue_elev  min_venue_elev
# 0         27.491907       25.222004
# 1          6.671440        5.781775
# 2         82.895638       76.947220
# 3          7.562148        7.249833
# 4          5.790783        3.726395
# ..              ...             ...
# 365      102.287842       95.371574
# 366       21.485924       14.810328
# 367       59.807091       55.070518
# 368       22.029186       21.810818
# 369        5.057438        3.463293
#
# [370 rows x 5 columns]

# %% [markdown]
# Merge station elevation with yelp venue elevation

# %%
elevation_comparison=pd.merge(stations, average_venue_elev, how='left', on='station_id')
elevation_comparison['average_elevation_delta']=elevation_comparison['elevation']-elevation_comparison['AVG(e.Elevation)']
elevation_comparison
#rename columns for clarity 
elevation_comparison.rename(columns={'AVG(e.Elevation)':'avg_venue_elev_100m'}, inplace=True)

elevation_comparison.rename(columns={'count(s.venue_id)':'venue_id_count'}, inplace=True)
elevation_comparison.rename(columns={'count(s.venue_id)':'venue_id_count'}, inplace=True)
elevation_comparison
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 1              6           5  983514094dd808b1604da2dcfc2d09af   37.336188
# 2             12          11  da17603652106fda93da4e255a5b0a22   37.322125
# 3             14           0  7a21c92b3b4cd2f7759107b4fdebf869   37.323678
# 4             24           2  ce34d38fb230a23c1ced12d1e16df294   37.325998
# ..           ...         ...                               ...         ...
# 519            5           0  d2ac19a2bb356f022983008bcd6ca5e1   37.767820
# 520            3           5  db8d54f6cc7dcbbf1d74783000539749   37.770938
# 521            5           0  6aba782b9e02d7ae351e6e9f81a7c330   37.768730
# 522            9          10  1b3d97eca9393abbf229aef9b3f80fda   37.731921
# 523           24           3  051b0abcc6ba494a27fc5ee5b0f8acf7   37.768384
#
#      longitude_x                        name                    timestamp  \
# 0    -122.270582     Harmon St at Adeline St  2023-08-22T02:33:57.545000Z
# 1    -121.889277  Fountain Alley at S 2nd St  2023-08-22T02:33:57.120000Z
# 2    -121.881090            Oak St at 1st St  2023-08-22T02:33:57.524000Z
# 3    -121.874119             Bestor Art Park  2023-08-22T02:33:57.243000Z
# 4    -121.877120       5th St at Virginia St  2023-08-22T02:33:57.456000Z
# ..           ...                         ...                          ...
# 519  -122.501868              Chain O' Lakes  2023-08-22T02:33:57.057000Z
# 520  -122.477116                  Stowe Lake  2023-08-22T02:33:57.058000Z
# 521  -122.459429               Bowling Green  2023-08-22T02:33:57.060000Z
# 522  -122.389886       Lane St at Revere Ave  2023-08-22T02:33:57.561000Z
# 523  -122.451967     Waller St at Shrader St  2023-08-22T02:33:57.428000Z
#
#      extra_ebikes  extra_has_ebikes  extra_last_updated  ...  \
# 0               0              True          1692671559  ...
# 1               0              True          1692671546  ...
# 2               0              True          1692671450  ...
# 3               0              True          1692671557  ...
# 4               1              True          1692671522  ...
# ..            ...               ...                 ...  ...
# 519             0              True          1691418718  ...
# 520             5              True          1691418745  ...
# 521             0              True          1691418758  ...
# 522             2              True          1692671481  ...
# 523             3              True          1692671543  ...
#
#                                 extra_uid  \
# 0    fd89514c-f878-4cd5-8113-8e5beead44de
# 1    d12ba265-5bfe-4a00-a19a-a7299822bd65
# 2    0fd9a51c-67ac-4048-b531-bff644b82f47
# 3    46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f
# 4    bb54f5c8-5578-4167-9599-8e55154de4fd
# ..                                    ...
# 519                   1841972814951361204
# 520                   1841972814951361202
# 521                   1841972814951361200
# 522  dfaaaa16-03ba-40b5-8360-6ebfc97ea541
# 523  7d15210b-55fb-4456-8281-781cfa9d5594
#
#                                          extra_address longitude_y latitude_y  \
# 0                                                  NaN -122.270582  37.849735
# 1                                                  NaN -121.889277  37.336188
# 2                                                  NaN -121.881090  37.322125
# 3                                                  NaN -121.874119  37.323678
# 4                                                  NaN -121.877120  37.325998
# ..                                                 ...         ...        ...
# 519  Chain of Lakes Dr E, San Francisco, CA 94121, ... -122.501868  37.767820
# 520  50 Stow Lake Dr, San Francisco, CA 94118, Unit... -122.477116  37.770938
# 521  Bowling Green Dr, San Francisco, CA 94118, Uni... -122.459429  37.768730
# 522                                                NaN -122.389886  37.731921
# 523                                                NaN -122.451967  37.768384
#
#      elevation  avg_venue_elev_100m  venue_id_count max_venue_elev  \
# 0    32.928356            32.567101             5.0      33.525723
# 1    25.925880            26.200848            18.0      26.928068
# 2    31.710926                  NaN             NaN            NaN
# 3    30.782372            30.878815             1.0      30.878815
# 4    30.175741                  NaN             NaN            NaN
# ..         ...                  ...             ...            ...
# 519  24.829159                  NaN             NaN            NaN
# 520  84.925842            85.710251             2.0      85.722527
# 521  76.045532                  NaN             NaN            NaN
# 522  26.973791                  NaN             NaN            NaN
# 523  82.717949            84.856185             6.0      85.674538
#
#     min_venue_elev  average_elevation_delta
# 0        31.480896                 0.361255
# 1        25.611631                -0.274968
# 2              NaN                      NaN
# 3        30.878815                -0.096443
# 4              NaN                      NaN
# ..             ...                      ...
# 519            NaN                      NaN
# 520      85.697975                -0.784409
# 521            NaN                      NaN
# 522            NaN                      NaN
# 523      83.181709                -2.138236
#
# [524 rows x 27 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = elevation_comparison

# Create a scatter plot
sns.scatterplot(data=df, x="elevation", y="avg_venue_elev_100m", hue="average_elevation_delta")

# Customize plot attributes
plt.title("Average Venue Elev within 100m of station vs Station Elevation")
plt.xlabel("Station Elevation")
plt.ylabel("Mean Venue Elevation")
plt.legend()

# Show the plot
plt.show()

# %%
# Set up Seaborn style
sns.set(style="whitegrid")

# Create a histogram
plt.figure(figsize=(8, 6))
sns.histplot(data=elevation_comparison, x="delta", bins=20, kde=True)  # Use kde=True for kernel density estimation
plt.title("Distribution of Values")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
#add total station size to elevation comparison
elevation_comparison['station_size']=elevation_comparison['free_bikes']+elevation_comparison['empty_slots']

# %%
elevation_comparison
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 1              6           5  983514094dd808b1604da2dcfc2d09af   37.336188
# 2             12          11  da17603652106fda93da4e255a5b0a22   37.322125
# 3             14           0  7a21c92b3b4cd2f7759107b4fdebf869   37.323678
# 4             24           2  ce34d38fb230a23c1ced12d1e16df294   37.325998
# ..           ...         ...                               ...         ...
# 519            5           0  d2ac19a2bb356f022983008bcd6ca5e1   37.767820
# 520            3           5  db8d54f6cc7dcbbf1d74783000539749   37.770938
# 521            5           0  6aba782b9e02d7ae351e6e9f81a7c330   37.768730
# 522            9          10  1b3d97eca9393abbf229aef9b3f80fda   37.731921
# 523           24           3  051b0abcc6ba494a27fc5ee5b0f8acf7   37.768384
#
#      longitude_x                        name                    timestamp  \
# 0    -122.270582     Harmon St at Adeline St  2023-08-22T02:33:57.545000Z
# 1    -121.889277  Fountain Alley at S 2nd St  2023-08-22T02:33:57.120000Z
# 2    -121.881090            Oak St at 1st St  2023-08-22T02:33:57.524000Z
# 3    -121.874119             Bestor Art Park  2023-08-22T02:33:57.243000Z
# 4    -121.877120       5th St at Virginia St  2023-08-22T02:33:57.456000Z
# ..           ...                         ...                          ...
# 519  -122.501868              Chain O' Lakes  2023-08-22T02:33:57.057000Z
# 520  -122.477116                  Stowe Lake  2023-08-22T02:33:57.058000Z
# 521  -122.459429               Bowling Green  2023-08-22T02:33:57.060000Z
# 522  -122.389886       Lane St at Revere Ave  2023-08-22T02:33:57.561000Z
# 523  -122.451967     Waller St at Shrader St  2023-08-22T02:33:57.428000Z
#
#      extra_ebikes  extra_has_ebikes  extra_last_updated  ... latitude_y  \
# 0               0              True          1692671559  ...  37.849735
# 1               0              True          1692671546  ...  37.336188
# 2               0              True          1692671450  ...  37.322125
# 3               0              True          1692671557  ...  37.323678
# 4               1              True          1692671522  ...  37.325998
# ..            ...               ...                 ...  ...        ...
# 519             0              True          1691418718  ...  37.767820
# 520             5              True          1691418745  ...  37.770938
# 521             0              True          1691418758  ...  37.768730
# 522             2              True          1692671481  ...  37.731921
# 523             3              True          1692671543  ...  37.768384
#
#      elevation avg_venue_elev_100m venue_id_count  max_venue_elev  \
# 0    32.928356           32.567101            5.0       33.525723
# 1    25.925880           26.200848           18.0       26.928068
# 2    31.710926                 NaN            NaN             NaN
# 3    30.782372           30.878815            1.0       30.878815
# 4    30.175741                 NaN            NaN             NaN
# ..         ...                 ...            ...             ...
# 519  24.829159                 NaN            NaN             NaN
# 520  84.925842           85.710251            2.0       85.722527
# 521  76.045532                 NaN            NaN             NaN
# 522  26.973791                 NaN            NaN             NaN
# 523  82.717949           84.856185            6.0       85.674538
#
#      min_venue_elev  average_elevation_delta station_size free_reg_bikes  \
# 0         31.480896                 0.361255           14             13
# 1         25.611631                -0.274968           11              5
# 2               NaN                      NaN           23             11
# 3         30.878815                -0.096443           14              0
# 4               NaN                      NaN           26              1
# ..              ...                      ...          ...            ...
# 519             NaN                      NaN            5              0
# 520       85.697975                -0.784409            8              0
# 521             NaN                      NaN            5              0
# 522             NaN                      NaN           19              8
# 523       83.181709                -2.138236           27              0
#
#      ebike_use_ratio
# 0               0.00
# 1               0.00
# 2               0.00
# 3                NaN
# 4               1.00
# ..               ...
# 519              NaN
# 520              inf
# 521              NaN
# 522             0.25
# 523              inf
#
# [524 rows x 30 columns]

# %%
elevation_comparison.sort_values('extra_ebikes')
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 280           12          13  02744ef00b430de0440ab88ecff71b2d   37.795195
# 152           11           8  c2e3051962238764d5e968e6f4544485   37.869060
# 153           21          10  33424dfd71dd02911d83b5b683e55791   37.771431
# 448           19           4  2c100d9e4d0c938b6ad09e600ca47359   37.811483
# ..           ...         ...                               ...         ...
# 345           10          29  f7897e831ad97c2fa5840e08da6bfaeb   37.778588
# 150            4          26  a7d703c1d843d22ee42adb5e6db291da   37.755367
# 108            3          25  1a8541216cf020de1dcf4f90c8fd0919   37.761634
# 339            2          27  f3005d50220aa753c49f411e3b76e170   37.795402
# 239            2          26  8744f3ffea155dd0b5e223031ace4513   37.800496
#
#      longitude_x                                   name  \
# 0    -122.270582                Harmon St at Adeline St
# 280  -122.273970                   Webster St at 2nd St
# 152  -122.293400              10th St at University Ave
# 153  -122.405787                   8th St at Brannan St
# 448  -122.260506                    Bay Pl at Vernon St
# ..           ...                                    ...
# 345  -122.392553                  3rd St at Townsend St
# 150  -122.388795                23rd St at Tennessee St
# 108  -122.390648  Esprit Park (19th St at Minnesota St)
# 339  -122.404689             Washington St at Kearny St
# 239  -122.410887              Powell St at Columbus Ave
#
#                        timestamp  extra_ebikes  extra_has_ebikes  \
# 0    2023-08-22T02:33:57.545000Z             0              True
# 280  2023-08-22T02:33:57.470000Z             0              True
# 152  2023-08-22T02:33:57.289000Z             0              True
# 153  2023-08-22T02:33:57.472000Z             0              True
# 448  2023-08-22T02:33:57.434000Z             0              True
# ..                           ...           ...               ...
# 345  2023-08-22T02:33:57.441000Z            20              True
# 150  2023-08-22T02:33:57.194000Z            23              True
# 108  2023-08-22T02:33:57.432000Z            24              True
# 339  2023-08-22T02:33:57.464000Z            25              True
# 239  2023-08-22T02:33:57.465000Z            26              True
#
#      extra_last_updated  ... longitude_y latitude_y  elevation  \
# 0            1692671559  ... -122.270582  37.849735  32.928356
# 280          1692671549  ... -122.273970  37.795195   4.394796
# 152          1692671549  ... -122.293400  37.869060  13.524503
# 153          1692671529  ... -122.405787  37.771431   3.992149
# 448          1692671526  ... -122.260506  37.811483   4.396778
# ..                  ...  ...         ...        ...        ...
# 345          1692671544  ... -122.392553  37.778588   6.358858
# 150          1692671516  ... -122.388795  37.755367   5.988184
# 108          1692671492  ... -122.390648  37.761634  13.508312
# 339          1692671543  ... -122.404689  37.795402  11.036342
# 239          1692671551  ... -122.410887  37.800496  23.995073
#
#     avg_venue_elev_100m  venue_id_count  average_elevation_delta  \
# 0             32.567101             5.0                 0.361255
# 280            4.512651             8.0                -0.117855
# 152           15.934305             3.0                -2.409802
# 153            4.490316             2.0                -0.498166
# 448            4.155405             3.0                 0.241373
# ..                  ...             ...                      ...
# 345            6.488930            11.0                -0.130072
# 150                 NaN             NaN                      NaN
# 108           13.308312             1.0                 0.200000
# 339           11.202712            19.0                -0.166370
# 239           23.215578            15.0                 0.779496
#
#      ebike_use_ratio sation_size station_size  free_reg_bikes
# 0           0.000000          14           14              13
# 280         0.000000          25           25              13
# 152         0.000000          19           19               8
# 153         0.000000          31           31              10
# 448         0.000000          23           23               4
# ..               ...         ...          ...             ...
# 345         2.000000          39           39               9
# 150         5.750000          30           30               3
# 108        12.000000          28           28               1
# 339         8.333333          29           29               2
# 239        26.000000          28           28               0
#
# [524 rows x 29 columns]

# %% [markdown]
# # Does the number of venues near the station seem to increase with elevation?

# %%
# Create a scatter plot
df=elevation_comparison
sns.scatterplot(data=df, x="elevation", y="venue_id_count", hue="average_elevation_delta")

# Customize plot attributes
plt.title("Count of Venue IDs vs Station Elevation")
plt.xlabel("Station Elevation")
plt.ylabel("venue_id_count")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# The number of stations seems to increase, but the number of venues doesn't appear to be related

# %% [markdown]
# Perhaps the ratio of free regular bikes changes with elevation to free ebikes

# %% [markdown]
# Free bikes counts all free bikes, and free_ebikes is only free ebikes so (free_bikes-free_ebikes)/free_bikes should give a ratio of free ebikes compared to free regular bikes

# %%
elevation_comparison['free_reg_bikes']=(elevation_comparison['free_bikes']-elevation_comparison['extra_ebikes'])

# %%
elevation_comparison['ebike_use_ratio']=(elevation_comparison['extra_ebikes']/((elevation_comparison['free_reg_bikes'])))

# %%
elevation_comparison['venue_range']=(elevation_comparison['max_venue_elev']-elevation_comparison['min_venue_elev'])

# %%
elevation_comparison.sort_values('ebike_use_ratio')
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 200            4          15  18ecb3d50f2e42cbeaa54e2700fa3093   37.840945
# 201           11           7  f72a227c01e328e88de3e27e883b5a42   37.840521
# 202            5          10  ff03a6199ba2f74b66752643531826ec   37.841924
# 203           15           4  cbdeb72b794ae1050a177368bee1364e   37.846784
# ..           ...         ...                               ...         ...
# 395            9           0  fda7185b4c97e338faf660d39aa119cb   37.875321
# 515           10           0  1c1e81258c2a201450e8dcf8d2b749d0   37.764869
# 517           15           0  fa1ea329b95e7733d38b7a6aab8e23d6   37.771700
# 519            5           0  d2ac19a2bb356f022983008bcd6ca5e1   37.767820
# 521            5           0  6aba782b9e02d7ae351e6e9f81a7c330   37.768730
#
#      longitude_x                                name  \
# 0    -122.270582             Harmon St at Adeline St
# 200  -122.291360                59th St at Horton St
# 201  -122.293528            Emeryville Public Market
# 202  -122.288045                 Doyle St at 59th St
# 203  -122.291376                65th St at Hollis St
# ..           ...                                 ...
# 395  -122.260155            Hearst Ave at Euclid Ave
# 515  -122.500498                          South Lake
# 517  -122.458282  Pompei Circle at John F Kennedy Dr
# 519  -122.501868                      Chain O' Lakes
# 521  -122.459429                       Bowling Green
#
#                        timestamp  extra_ebikes  extra_has_ebikes  \
# 0    2023-08-22T02:33:57.545000Z             0              True
# 200  2023-08-22T02:33:57.453000Z             0              True
# 201  2023-08-22T02:33:57.193000Z             0              True
# 202  2023-08-22T02:33:57.329000Z             0              True
# 203  2023-08-22T02:33:57.381000Z             0              True
# ..                           ...           ...               ...
# 395  2023-08-22T02:33:57.266000Z             0              True
# 515  2023-08-22T02:33:57.055000Z             0              True
# 517  2023-08-22T02:33:57.139000Z             0              True
# 519  2023-08-22T02:33:57.057000Z             0              True
# 521  2023-08-22T02:33:57.060000Z             0              True
#
#      extra_last_updated  ... latitude_y  elevation avg_venue_elev_100m  \
# 0            1692671559  ...  37.849735  32.928356           32.567101
# 200          1692671560  ...  37.840945   5.453859            5.480060
# 201          1692671508  ...  37.840521   3.151343            3.954656
# 202          1692671512  ...  37.841924   7.981547                 NaN
# 203          1692671489  ...  37.846784   7.060003            7.296653
# ..                  ...  ...        ...        ...                 ...
# 395          1692671495  ...  37.875321  96.669136           98.539898
# 515          1691416974  ...  37.764869  27.959616           25.993872
# 517          1692671484  ...  37.771700  74.926872           74.172000
# 519          1691418718  ...  37.767820  24.829159                 NaN
# 521          1691418758  ...  37.768730  76.045532                 NaN
#
#     venue_id_count  max_venue_elev  min_venue_elev  average_elevation_delta  \
# 0              5.0       33.525723       31.480896                 0.361255
# 200            3.0        5.922227        5.211890                -0.026201
# 201           10.0        4.014022        3.892612                -0.803312
# 202            NaN             NaN             NaN                      NaN
# 203            5.0        8.228651        6.863261                -0.236651
# ..             ...             ...             ...                      ...
# 395           16.0      102.287842       95.371574                -1.870762
# 515            1.0       25.993872       25.993872                 1.965744
# 517            3.0       74.772408       72.990364                 0.754873
# 519            NaN             NaN             NaN                      NaN
# 521            NaN             NaN             NaN                      NaN
#
#     station_size free_reg_bikes  ebike_use_ratio
# 0             14             13              0.0
# 200           19             15              0.0
# 201           18              7              0.0
# 202           15             10              0.0
# 203           19              4              0.0
# ..           ...            ...              ...
# 395            9              0              NaN
# 515           10              0              NaN
# 517           15              0              NaN
# 519            5              0              NaN
# 521            5              0              NaN
#
# [524 rows x 30 columns]

# %%
sbn.regplot(data=elevation_comparison, x='extra_slots', y='station_size', scatter_kws={'alpha':0.15})
# Out:
# <Axes: xlabel='extra_slots', ylabel='station_size'>

# %%
#replace values where ebike_use_ratio is NaN, caused by divide by zero, ie, no free bikes with the ratio of empty ebike slots to free bike slots
elevation_comparison['ebike_base_ratio']=(elevation_comparison['empty_slots']+elevation_comparison['free_bikes'])

# %%
# Create a scatter plot
df=elevation_comparison
sns.scatterplot(data=df, x="elevation", y="ebike_use_ratio", hue="average_elevation_delta")

# Customize plot attributes
plt.title("ebike_use_ratio vs Station Elevation")
plt.xlabel("Station Elevation")
plt.ylabel("ebike_use_ratio")
plt.legend()

# Show the plot
plt.show()

# %%
sbn.regplot(data=elevation_comparison, x='ebike_use_ratio', y='elevation', scatter_kws={'alpha':0.15})
# Out:
# <Axes: xlabel='ebike_use_ratio', ylabel='elevation'>

# %%
# add elevations comparisons as a new database in sqlite

df = elevation_comparison

table_name = 'elevation_comparison'

conn = sqlite3.connect('CityBike_Project.db')
query = f'Create table if not Exists {table_name} (station_id TEXT PRIMARY KEY)'
conn.execute(query)
df.to_sql(table_name,conn,if_exists='replace',index=False)
conn.commit()
conn.close()

# %%
elevation_comparison.to_csv('elevation_comparison.csv', index=False)

# %%
elevation_comparison.drop('sation_size', axis=1) #remove typo
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 1              6           5  983514094dd808b1604da2dcfc2d09af   37.336188
# 2             12          11  da17603652106fda93da4e255a5b0a22   37.322125
# 3             14           0  7a21c92b3b4cd2f7759107b4fdebf869   37.323678
# 4             24           2  ce34d38fb230a23c1ced12d1e16df294   37.325998
# ..           ...         ...                               ...         ...
# 519            5           0  d2ac19a2bb356f022983008bcd6ca5e1   37.767820
# 520            3           5  db8d54f6cc7dcbbf1d74783000539749   37.770938
# 521            5           0  6aba782b9e02d7ae351e6e9f81a7c330   37.768730
# 522            9          10  1b3d97eca9393abbf229aef9b3f80fda   37.731921
# 523           24           3  051b0abcc6ba494a27fc5ee5b0f8acf7   37.768384
#
#      longitude_x                        name                    timestamp  \
# 0    -122.270582     Harmon St at Adeline St  2023-08-22T02:33:57.545000Z
# 1    -121.889277  Fountain Alley at S 2nd St  2023-08-22T02:33:57.120000Z
# 2    -121.881090            Oak St at 1st St  2023-08-22T02:33:57.524000Z
# 3    -121.874119             Bestor Art Park  2023-08-22T02:33:57.243000Z
# 4    -121.877120       5th St at Virginia St  2023-08-22T02:33:57.456000Z
# ..           ...                         ...                          ...
# 519  -122.501868              Chain O' Lakes  2023-08-22T02:33:57.057000Z
# 520  -122.477116                  Stowe Lake  2023-08-22T02:33:57.058000Z
# 521  -122.459429               Bowling Green  2023-08-22T02:33:57.060000Z
# 522  -122.389886       Lane St at Revere Ave  2023-08-22T02:33:57.561000Z
# 523  -122.451967     Waller St at Shrader St  2023-08-22T02:33:57.428000Z
#
#      extra_ebikes  extra_has_ebikes  extra_last_updated  ...  \
# 0               0              True          1692671559  ...
# 1               0              True          1692671546  ...
# 2               0              True          1692671450  ...
# 3               0              True          1692671557  ...
# 4               1              True          1692671522  ...
# ..            ...               ...                 ...  ...
# 519             0              True          1691418718  ...
# 520             5              True          1691418745  ...
# 521             0              True          1691418758  ...
# 522             2              True          1692671481  ...
# 523             3              True          1692671543  ...
#
#                                          extra_address longitude_y latitude_y  \
# 0                                                  NaN -122.270582  37.849735
# 1                                                  NaN -121.889277  37.336188
# 2                                                  NaN -121.881090  37.322125
# 3                                                  NaN -121.874119  37.323678
# 4                                                  NaN -121.877120  37.325998
# ..                                                 ...         ...        ...
# 519  Chain of Lakes Dr E, San Francisco, CA 94121, ... -122.501868  37.767820
# 520  50 Stow Lake Dr, San Francisco, CA 94118, Unit... -122.477116  37.770938
# 521  Bowling Green Dr, San Francisco, CA 94118, Uni... -122.459429  37.768730
# 522                                                NaN -122.389886  37.731921
# 523                                                NaN -122.451967  37.768384
#
#      elevation  avg_venue_elev_100m  venue_id_count  average_elevation_delta  \
# 0    32.928356            32.567101             5.0                 0.361255
# 1    25.925880            26.200848            18.0                -0.274968
# 2    31.710926                  NaN             NaN                      NaN
# 3    30.782372            30.878815             1.0                -0.096443
# 4    30.175741                  NaN             NaN                      NaN
# ..         ...                  ...             ...                      ...
# 519  24.829159                  NaN             NaN                      NaN
# 520  84.925842            85.710251             2.0                -0.784409
# 521  76.045532                  NaN             NaN                      NaN
# 522  26.973791                  NaN             NaN                      NaN
# 523  82.717949            84.856185             6.0                -2.138236
#
#     ebike_use_ratio station_size  free_reg_bikes
# 0          0.000000           14              13
# 1          0.000000           11               5
# 2          0.000000           23              11
# 3          0.000000           14               0
# 4          0.500000           26               1
# ..              ...          ...             ...
# 519        0.000000            5               0
# 520        5.000000            8               0
# 521        0.000000            5               0
# 522        0.222222           19               8
# 523        3.000000           27               0
#
# [524 rows x 28 columns]

# %%
#filling rows that found no venues with zero and replacing station elev with avg venue elev
#columns_to_fill = ['venue_id_count', 'average_elevation_delta']
fill_values = {'venue_id_count': 0, 'average_elevation_delta': 0}  # Replace NaN with 0 for these columns
elevation_comparison['venue_id_count'].fillna(0, inplace=True)
elevation_comparison['average_elevation_delta'].fillna(0, inplace=True)
elevation_comparison['avg_venue_elev_100m'].fillna(elevation_comparison['elevation'], inplace=True)
elevation_comparison['venue_range'].fillna(0, inplace=True)
elevation_comparison['max_venue_elev'].fillna(elevation_comparison['elevation'], inplace=True)
elevation_comparison['min_venue_elev'].fillna(elevation_comparison['elevation'], inplace=True)

# %%
elevation_comparison
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 1              6           5  983514094dd808b1604da2dcfc2d09af   37.336188
# 2             12          11  da17603652106fda93da4e255a5b0a22   37.322125
# 3             14           0  7a21c92b3b4cd2f7759107b4fdebf869   37.323678
# 4             24           2  ce34d38fb230a23c1ced12d1e16df294   37.325998
# ..           ...         ...                               ...         ...
# 519            5           0  d2ac19a2bb356f022983008bcd6ca5e1   37.767820
# 520            3           5  db8d54f6cc7dcbbf1d74783000539749   37.770938
# 521            5           0  6aba782b9e02d7ae351e6e9f81a7c330   37.768730
# 522            9          10  1b3d97eca9393abbf229aef9b3f80fda   37.731921
# 523           24           3  051b0abcc6ba494a27fc5ee5b0f8acf7   37.768384
#
#      longitude_x                        name                    timestamp  \
# 0    -122.270582     Harmon St at Adeline St  2023-08-22T02:33:57.545000Z
# 1    -121.889277  Fountain Alley at S 2nd St  2023-08-22T02:33:57.120000Z
# 2    -121.881090            Oak St at 1st St  2023-08-22T02:33:57.524000Z
# 3    -121.874119             Bestor Art Park  2023-08-22T02:33:57.243000Z
# 4    -121.877120       5th St at Virginia St  2023-08-22T02:33:57.456000Z
# ..           ...                         ...                          ...
# 519  -122.501868              Chain O' Lakes  2023-08-22T02:33:57.057000Z
# 520  -122.477116                  Stowe Lake  2023-08-22T02:33:57.058000Z
# 521  -122.459429               Bowling Green  2023-08-22T02:33:57.060000Z
# 522  -122.389886       Lane St at Revere Ave  2023-08-22T02:33:57.561000Z
# 523  -122.451967     Waller St at Shrader St  2023-08-22T02:33:57.428000Z
#
#      extra_ebikes  extra_has_ebikes  extra_last_updated  ...  elevation  \
# 0               0              True          1692671559  ...  32.928356
# 1               0              True          1692671546  ...  25.925880
# 2               0              True          1692671450  ...  31.710926
# 3               0              True          1692671557  ...  30.782372
# 4               1              True          1692671522  ...  30.175741
# ..            ...               ...                 ...  ...        ...
# 519             0              True          1691418718  ...  24.829159
# 520             5              True          1691418745  ...  84.925842
# 521             0              True          1691418758  ...  76.045532
# 522             2              True          1692671481  ...  26.973791
# 523             3              True          1692671543  ...  82.717949
#
#     avg_venue_elev_100m venue_id_count max_venue_elev  min_venue_elev  \
# 0             32.567101            5.0      33.525723       31.480896
# 1             26.200848           18.0      26.928068       25.611631
# 2             31.710926            0.0            NaN             NaN
# 3             30.878815            1.0      30.878815       30.878815
# 4             30.175741            0.0            NaN             NaN
# ..                  ...            ...            ...             ...
# 519           24.829159            0.0            NaN             NaN
# 520           85.710251            2.0      85.722527       85.697975
# 521           76.045532            0.0            NaN             NaN
# 522           26.973791            0.0            NaN             NaN
# 523           84.856185            6.0      85.674538       83.181709
#
#      average_elevation_delta  station_size free_reg_bikes ebike_use_ratio  \
# 0                   0.361255            14             13            0.00
# 1                  -0.274968            11              5            0.00
# 2                   0.000000            23             11            0.00
# 3                  -0.096443            14              0             NaN
# 4                   0.000000            26              1            1.00
# ..                       ...           ...            ...             ...
# 519                 0.000000             5              0             NaN
# 520                -0.784409             8              0             inf
# 521                 0.000000             5              0             NaN
# 522                 0.000000            19              8            0.25
# 523                -2.138236            27              0             inf
#
#      venue_range
# 0       2.044827
# 1       1.316437
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ..           ...
# 519     0.000000
# 520     0.024551
# 521     0.000000
# 522     0.000000
# 523     2.492828
#
# [524 rows x 31 columns]

# %%
elevation_comparison['station_avg_uphill_yes']=np.where(elevation_comparison['average_elevation_delta']>=0,1,0)

# %%
elevation_comparison.to_csv('elevation_comparison.csv', index=False)

# %%
elevation_comparison.drop('sation_size', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 elevation_comparison.drop('sation_size', axis=1, inplace=True)
#
# File ~\.conda\envs\lhl_base_env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\.conda\envs\lhl_base_env\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\.conda\envs\lhl_base_env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\.conda\envs\lhl_base_env\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\.conda\envs\lhl_base_env\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\.conda\envs\lhl_base_env\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['sation_size'] not found in axis"

# %%
elevation_comparison.to_csv('elevation_comparison.csv', index=False)

# %% [markdown]
# Import hourly city bike data

# %%
elevation_comparison
# Out:
#      empty_slots  free_bikes                        station_id  latitude_x  \
# 0              1          13  d0e8f4f1834b7b33a3faf8882f567ab8   37.849735
# 1              6           5  983514094dd808b1604da2dcfc2d09af   37.336188
# 2             12          11  da17603652106fda93da4e255a5b0a22   37.322125
# 3             14           0  7a21c92b3b4cd2f7759107b4fdebf869   37.323678
# 4             24           2  ce34d38fb230a23c1ced12d1e16df294   37.325998
# ..           ...         ...                               ...         ...
# 519            5           0  d2ac19a2bb356f022983008bcd6ca5e1   37.767820
# 520            3           5  db8d54f6cc7dcbbf1d74783000539749   37.770938
# 521            5           0  6aba782b9e02d7ae351e6e9f81a7c330   37.768730
# 522            9          10  1b3d97eca9393abbf229aef9b3f80fda   37.731921
# 523           24           3  051b0abcc6ba494a27fc5ee5b0f8acf7   37.768384
#
#      longitude_x                        name                    timestamp  \
# 0    -122.270582     Harmon St at Adeline St  2023-08-22T02:33:57.545000Z
# 1    -121.889277  Fountain Alley at S 2nd St  2023-08-22T02:33:57.120000Z
# 2    -121.881090            Oak St at 1st St  2023-08-22T02:33:57.524000Z
# 3    -121.874119             Bestor Art Park  2023-08-22T02:33:57.243000Z
# 4    -121.877120       5th St at Virginia St  2023-08-22T02:33:57.456000Z
# ..           ...                         ...                          ...
# 519  -122.501868              Chain O' Lakes  2023-08-22T02:33:57.057000Z
# 520  -122.477116                  Stowe Lake  2023-08-22T02:33:57.058000Z
# 521  -122.459429               Bowling Green  2023-08-22T02:33:57.060000Z
# 522  -122.389886       Lane St at Revere Ave  2023-08-22T02:33:57.561000Z
# 523  -122.451967     Waller St at Shrader St  2023-08-22T02:33:57.428000Z
#
#      extra_ebikes  extra_has_ebikes  extra_last_updated  ...  \
# 0               0              True          1692671559  ...
# 1               0              True          1692671546  ...
# 2               0              True          1692671450  ...
# 3               0              True          1692671557  ...
# 4               1              True          1692671522  ...
# ..            ...               ...                 ...  ...
# 519             0              True          1691418718  ...
# 520             5              True          1691418745  ...
# 521             0              True          1691418758  ...
# 522             2              True          1692671481  ...
# 523             3              True          1692671543  ...
#
#     avg_venue_elev_100m venue_id_count max_venue_elev min_venue_elev  \
# 0             32.567101            5.0      33.525723      31.480896
# 1             26.200848           18.0      26.928068      25.611631
# 2             31.710926            0.0            NaN            NaN
# 3             30.878815            1.0      30.878815      30.878815
# 4             30.175741            0.0            NaN            NaN
# ..                  ...            ...            ...            ...
# 519           24.829159            0.0            NaN            NaN
# 520           85.710251            2.0      85.722527      85.697975
# 521           76.045532            0.0            NaN            NaN
# 522           26.973791            0.0            NaN            NaN
# 523           84.856185            6.0      85.674538      83.181709
#
#      average_elevation_delta  station_size  free_reg_bikes ebike_use_ratio  \
# 0                   0.361255            14              13            0.00
# 1                  -0.274968            11               5            0.00
# 2                   0.000000            23              11            0.00
# 3                  -0.096443            14               0             NaN
# 4                   0.000000            26               1            1.00
# ..                       ...           ...             ...             ...
# 519                 0.000000             5               0             NaN
# 520                -0.784409             8               0             inf
# 521                 0.000000             5               0             NaN
# 522                 0.000000            19               8            0.25
# 523                -2.138236            27               0             inf
#
#     venue_range  station_avg_uphill_yes
# 0      2.044827                       1
# 1      1.316437                       0
# 2      0.000000                       1
# 3      0.000000                       0
# 4      0.000000                       1
# ..          ...                     ...
# 519    0.000000                       1
# 520    0.024551                       0
# 521    0.000000                       1
# 522    0.000000                       1
# 523    2.492828                       0
#
# [524 rows x 32 columns]

# %%
# Connect to the SQLite database
conn = sqlite3.connect("hr.db")  # Replace with your database name

# Close the connection
conn.close()

# %%
conn = sqlite3.connect('hr.db')
# Create a cursor object
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
table_names = cursor.fetchall()
table_names
# Out:
# [('regions',),
#  ('sqlite_sequence',),
#  ('countries',),
#  ('locations',),
#  ('departments',),
#  ('jobs',),
#  ('employees',),
#  ('dependents',)]

# %%
cursor.execute("SELECT * FROM employees;")
rows = cursor.fetchall()
df = pd.DataFrame(rows, columns=[col[0] for col in cursor.description])

# %%
df
# Out:
#     employee_id   first_name    last_name                              email  \
# 0           100       Steven         King        steven.king@sqltutorial.org
# 1           101        Neena      Kochhar      neena.kochhar@sqltutorial.org
# 2           102          Lex      De Haan        lex.de haan@sqltutorial.org
# 3           103    Alexander       Hunold   alexander.hunold@sqltutorial.org
# 4           104        Bruce        Ernst        bruce.ernst@sqltutorial.org
# 5           105        David       Austin       david.austin@sqltutorial.org
# 6           106        Valli    Pataballa    valli.pataballa@sqltutorial.org
# 7           107        Diana      Lorentz      diana.lorentz@sqltutorial.org
# 8           108        Nancy    Greenberg    nancy.greenberg@sqltutorial.org
# 9           109       Daniel       Faviet      daniel.faviet@sqltutorial.org
# 10          110         John         Chen          john.chen@sqltutorial.org
# 11          111       Ismael      Sciarra     ismael.sciarra@sqltutorial.org
# 12          112  Jose Manuel        Urman  jose manuel.urman@sqltutorial.org
# 13          113         Luis         Popp          luis.popp@sqltutorial.org
# 14          114          Den     Raphaely       den.raphaely@sqltutorial.org
# 15          115    Alexander         Khoo     alexander.khoo@sqltutorial.org
# 16          116       Shelli        Baida       shelli.baida@sqltutorial.org
# 17          117        Sigal       Tobias       sigal.tobias@sqltutorial.org
# 18          118          Guy       Himuro         guy.himuro@sqltutorial.org
# 19          119        Karen   Colmenares   karen.colmenares@sqltutorial.org
# 20          120      Matthew        Weiss      matthew.weiss@sqltutorial.org
# 21          121         Adam        Fripp         adam.fripp@sqltutorial.org
# 22          122        Payam     Kaufling     payam.kaufling@sqltutorial.org
# 23          123       Shanta      Vollman     shanta.vollman@sqltutorial.org
# 24          126        Irene  Mikkilineni  irene.mikkilineni@sqltutorial.org
# 25          145         John      Russell       john.russell@sqltutorial.org
# 26          146        Karen     Partners     karen.partners@sqltutorial.org
# 27          176     Jonathon       Taylor    jonathon.taylor@sqltutorial.org
# 28          177         Jack   Livingston    jack.livingston@sqltutorial.org
# 29          178    Kimberely        Grant    kimberely.grant@sqltutorial.org
# 30          179      Charles      Johnson    charles.johnson@sqltutorial.org
# 31          192        Sarah         Bell         sarah.bell@sqltutorial.org
# 32          193      Britney      Everett    britney.everett@sqltutorial.org
# 33          200     Jennifer       Whalen    jennifer.whalen@sqltutorial.org
# 34          201      Michael    Hartstein  michael.hartstein@sqltutorial.org
# 35          202          Pat          Fay            pat.fay@sqltutorial.org
# 36          203        Susan       Mavris       susan.mavris@sqltutorial.org
# 37          204      Hermann         Baer       hermann.baer@sqltutorial.org
# 38          205      Shelley      Higgins    shelley.higgins@sqltutorial.org
# 39          206      William        Gietz      william.gietz@sqltutorial.org
#
#     phone_number   hire_date  job_id   salary  manager_id  department_id
# 0   515.123.4567  1987-06-17       4  24000.0         NaN              9
# 1   515.123.4568  1989-09-21       5  17000.0       100.0              9
# 2   515.123.4569  1993-01-13       5  17000.0       100.0              9
# 3   590.423.4567  1990-01-03       9   9000.0       102.0              6
# 4   590.423.4568  1991-05-21       9   6000.0       103.0              6
# 5   590.423.4569  1997-06-25       9   4800.0       103.0              6
# 6   590.423.4560  1998-02-05       9   4800.0       103.0              6
# 7   590.423.5567  1999-02-07       9   4200.0       103.0              6
# 8   515.124.4569  1994-08-17       7  12000.0       101.0             10
# 9   515.124.4169  1994-08-16       6   9000.0       108.0             10
# 10  515.124.4269  1997-09-28       6   8200.0       108.0             10
# 11  515.124.4369  1997-09-30       6   7700.0       108.0             10
# 12  515.124.4469  1998-03-07       6   7800.0       108.0             10
# 13  515.124.4567  1999-12-07       6   6900.0       108.0             10
# 14  515.127.4561  1994-12-07      14  11000.0       100.0              3
# 15  515.127.4562  1995-05-18      13   3100.0       114.0              3
# 16  515.127.4563  1997-12-24      13   2900.0       114.0              3
# 17  515.127.4564  1997-07-24      13   2800.0       114.0              3
# 18  515.127.4565  1998-11-15      13   2600.0       114.0              3
# 19  515.127.4566  1999-08-10      13   2500.0       114.0              3
# 20  650.123.1234  1996-07-18      19   8000.0       100.0              5
# 21  650.123.2234  1997-04-10      19   8200.0       100.0              5
# 22  650.123.3234  1995-05-01      19   7900.0       100.0              5
# 23  650.123.4234  1997-10-10      19   6500.0       100.0              5
# 24  650.124.1224  1998-09-28      18   2700.0       120.0              5
# 25          None  1996-10-01      15  14000.0       100.0              8
# 26          None  1997-01-05      15  13500.0       100.0              8
# 27          None  1998-03-24      16   8600.0       100.0              8
# 28          None  1998-04-23      16   8400.0       100.0              8
# 29          None  1999-05-24      16   7000.0       100.0              8
# 30          None  2000-01-04      16   6200.0       100.0              8
# 31  650.501.1876  1996-02-04      17   4000.0       123.0              5
# 32  650.501.2876  1997-03-03      17   3900.0       123.0              5
# 33  515.123.4444  1987-09-17       3   4400.0       101.0              1
# 34  515.123.5555  1996-02-17      10  13000.0       100.0              2
# 35  603.123.6666  1997-08-17      11   6000.0       201.0              2
# 36  515.123.7777  1994-06-07       8   6500.0       101.0              4
# 37  515.123.8888  1994-06-07      12  10000.0       101.0              7
# 38  515.123.8080  1994-06-07       2  12000.0       101.0             11
# 39  515.123.8181  1994-06-07       1   8300.0       205.0             11

# %%
#Write a query to display the names (first_name, last_name) and department ID of all employees in departments 3 or 10 in ascending order by department ID.
conn = sqlite3.connect('hr.db')
# Create a cursor object
cursor = conn.cursor()
query = """
SELECT s.station_id, AVG(e.Elevation), count(s.venue_id),MAX(e.Elevation) max_venue_elev,MIN(e.Elevation) min_venue_elev
FROM employees e
JOIN departments d ON s.venue_id = e.yelp_venue_id
GROUP BY s.station_id
"""
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
table_names = cursor.fetchall()
table_names
# Out:
# [('regions',),
#  ('sqlite_sequence',),
#  ('countries',),
#  ('locations',),
#  ('departments',),
#  ('jobs',),
#  ('employees',),
#  ('dependents',)]

# %%
#Write a query to display the names (first_name, last_name) and department ID of all employees in departments 3 or 10 in ascending order by department ID.df
# Out:
#             full_name   salary      PF
# 0         Steven King  24000.0  2880.0
# 1       Neena Kochhar  17000.0  2040.0
# 2         Lex De Haan  17000.0  2040.0
# 3    Alexander Hunold   9000.0  1080.0
# 4         Bruce Ernst   6000.0   720.0
# 5        David Austin   4800.0   576.0
# 6     Valli Pataballa   4800.0   576.0
# 7       Diana Lorentz   4200.0   504.0
# 8     Nancy Greenberg  12000.0  1440.0
# 9       Daniel Faviet   9000.0  1080.0
# 10          John Chen   8200.0   984.0
# 11     Ismael Sciarra   7700.0   924.0
# 12  Jose Manuel Urman   7800.0   936.0
# 13          Luis Popp   6900.0   828.0
# 14       Den Raphaely  11000.0  1320.0
# 15     Alexander Khoo   3100.0   372.0
# 16       Shelli Baida   2900.0   348.0
# 17       Sigal Tobias   2800.0   336.0
# 18         Guy Himuro   2600.0   312.0
# 19   Karen Colmenares   2500.0   300.0
# 20      Matthew Weiss   8000.0   960.0
# 21         Adam Fripp   8200.0   984.0
# 22     Payam Kaufling   7900.0   948.0
# 23     Shanta Vollman   6500.0   780.0
# 24  Irene Mikkilineni   2700.0   324.0
# 25       John Russell  14000.0  1680.0
# 26     Karen Partners  13500.0  1620.0
# 27    Jonathon Taylor   8600.0  1032.0
# 28    Jack Livingston   8400.0  1008.0
# 29    Kimberely Grant   7000.0   840.0
# 30    Charles Johnson   6200.0   744.0
# 31         Sarah Bell   4000.0   480.0
# 32    Britney Everett   3900.0   468.0
# 33    Jennifer Whalen   4400.0   528.0
# 34  Michael Hartstein  13000.0  1560.0
# 35            Pat Fay   6000.0   720.0
# 36       Susan Mavris   6500.0   780.0
# 37       Hermann Baer  10000.0  1200.0
# 38    Shelley Higgins  12000.0  1440.0
# 39      William Gietz   8300.0   996.0

# %%
#Write a query to display the names (first_name, last_name) and department ID of all employees in departments 3 or 10 in ascending order by department ID.
query = """
SELECT first_name, last_name,department_id  
FROM employees
WHERE department_id = 3 OR department_id = 10;
"""
cursor.execute(query)
rows = cursor.fetchall()
df = pd.DataFrame(rows, columns=[col[0] for col in cursor.description])
df
# Out:
#      first_name   last_name  department_id
# 0         Nancy   Greenberg             10
# 1        Daniel      Faviet             10
# 2          John        Chen             10
# 3        Ismael     Sciarra             10
# 4   Jose Manuel       Urman             10
# 5          Luis        Popp             10
# 6           Den    Raphaely              3
# 7     Alexander        Khoo              3
# 8        Shelli       Baida              3
# 9         Sigal      Tobias              3
# 10          Guy      Himuro              3
# 11        Karen  Colmenares              3

# %%
query = """
SELECT s.station_id, AVG(e.Elevation), count(s.venue_id),MAX(e.Elevation) max_venue_elev,MIN(e.Elevation) min_venue_elev
FROM stations_venues_yelp_melted s
JOIN yelp_venue_elev e ON s.venue_id = e.yelp_venue_id
GROUP BY s.station_id
"""
connection.close()
